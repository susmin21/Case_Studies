# %% [markdown]
# # Excercise

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\susmi\DSA\diamonds_new.csv')

# %%
df
# Out:
#        carat        cut color clarity  table     x     y     z  price_new
# 0       0.23      Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1       0.21    Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2       0.23       Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3       0.29    Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4       0.31       Good     J     SI2   58.0  4.34  4.35  2.75      167.5
# ...      ...        ...   ...     ...    ...   ...   ...   ...        ...
# 53935   0.72      Ideal     D     SI1   57.0  5.75  5.76  3.50     1378.5
# 53936   0.72       Good     D     SI1   55.0  5.69  5.75  3.61     1378.5
# 53937   0.70  Very Good     D     SI1   60.0  5.66  5.68  3.56     1378.5
# 53938   0.86    Premium     H     SI2   58.0  6.15  6.12  3.74     1378.5
# 53939   0.75      Ideal     D     SI2   55.0  5.83  5.87  3.64     1378.5
#
# [53940 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'table', 'x', 'y', 'z',
#        'price_new'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   carat      53841 non-null  float64
#  1   cut        53940 non-null  object
#  2   color      53884 non-null  object
#  3   clarity    53940 non-null  object
#  4   table      53877 non-null  float64
#  5   x          53940 non-null  float64
#  6   y          53940 non-null  float64
#  7   z          53940 non-null  float64
#  8   price_new  53940 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# carat        99
# cut           0
# color        56
# clarity       0
# table        63
# x             0
# y             0
# z             0
# price_new     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

column_to_encode = 'color'
column_to_encode_values = df[column_to_encode]

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(column_to_encode_values)

df['encoded_color'] = encoded_labels

# %%
df
# Out:
#        carat        cut color clarity  table     x     y     z  price_new  \
# 0       0.23      Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1       0.21    Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2       0.23       Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3       0.29    Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4       0.31       Good     J     SI2   58.0  4.34  4.35  2.75      167.5
# ...      ...        ...   ...     ...    ...   ...   ...   ...        ...
# 53935   0.72      Ideal     D     SI1   57.0  5.75  5.76  3.50     1378.5
# 53936   0.72       Good     D     SI1   55.0  5.69  5.75  3.61     1378.5
# 53937   0.70  Very Good     D     SI1   60.0  5.66  5.68  3.56     1378.5
# 53938   0.86    Premium     H     SI2   58.0  6.15  6.12  3.74     1378.5
# 53939   0.75      Ideal     D     SI2   55.0  5.83  5.87  3.64     1378.5
#
#        encoded_color
# 0                  1
# 1                  1
# ...

# %%
from sklearn.preprocessing import LabelEncoder

column_to_encode = 'cut'
column_to_encode_values = df[column_to_encode]

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(column_to_encode_values)

df['encoded_cut'] = encoded_labels

# %%
df
# Out:
#        carat        cut color clarity  table     x     y     z  price_new  \
# 0       0.23      Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1       0.21    Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2       0.23       Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3       0.29    Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4       0.31       Good     J     SI2   58.0  4.34  4.35  2.75      167.5
# ...      ...        ...   ...     ...    ...   ...   ...   ...        ...
# 53935   0.72      Ideal     D     SI1   57.0  5.75  5.76  3.50     1378.5
# 53936   0.72       Good     D     SI1   55.0  5.69  5.75  3.61     1378.5
# 53937   0.70  Very Good     D     SI1   60.0  5.66  5.68  3.56     1378.5
# 53938   0.86    Premium     H     SI2   58.0  6.15  6.12  3.74     1378.5
# 53939   0.75      Ideal     D     SI2   55.0  5.83  5.87  3.64     1378.5
#
#        encoded_color  encoded_cut
# 0                  1            2
# ...

# %%
from sklearn.preprocessing import LabelEncoder

column_to_encode = 'clarity'
column_to_encode_values = df[column_to_encode]

label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(column_to_encode_values)

df['encoded_clarity'] = encoded_labels

# %%
df
# Out:
#        carat        cut color clarity  table     x     y     z  price_new  \
# 0       0.23      Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1       0.21    Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2       0.23       Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3       0.29    Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4       0.31       Good     J     SI2   58.0  4.34  4.35  2.75      167.5
# ...      ...        ...   ...     ...    ...   ...   ...   ...        ...
# 53935   0.72      Ideal     D     SI1   57.0  5.75  5.76  3.50     1378.5
# 53936   0.72       Good     D     SI1   55.0  5.69  5.75  3.61     1378.5
# 53937   0.70  Very Good     D     SI1   60.0  5.66  5.68  3.56     1378.5
# 53938   0.86    Premium     H     SI2   58.0  6.15  6.12  3.74     1378.5
# 53939   0.75      Ideal     D     SI2   55.0  5.83  5.87  3.64     1378.5
#
#        encoded_color  encoded_cut  encoded_clarity
# ...

# %%
df = df.drop(['cut','color','clarity'],axis = 1)

# %%
df
# Out:
#        carat  table     x     y     z  price_new  encoded_color  encoded_cut  \
# 0       0.23   55.0  3.95  3.98  2.43      163.0              1            2
# 1       0.21   61.0  3.89  3.84  2.31      163.0              1            3
# 2       0.23   65.0  4.05  4.07  2.31      163.5              1            1
# 3       0.29   58.0  4.20  4.23  2.63      167.0              5            3
# 4       0.31   58.0  4.34  4.35  2.75      167.5              6            1
# ...      ...    ...   ...   ...   ...        ...            ...          ...
# 53935   0.72   57.0  5.75  5.76  3.50     1378.5              0            2
# 53936   0.72   55.0  5.69  5.75  3.61     1378.5              0            1
# 53937   0.70   60.0  5.66  5.68  3.56     1378.5              0            4
# 53938   0.86   58.0  6.15  6.12  3.74     1378.5              4            3
# 53939   0.75   55.0  5.83  5.87  3.64     1378.5              0            2
#
#        encoded_clarity
# ...

# %%
df.corr()
# Out:
#                     carat     table         x         y         z  price_new  \
# carat            1.000000  0.182037  0.975127  0.951753  0.958075   0.921611
# table            0.182037  1.000000  0.195338  0.183756  0.151758   0.127068
# x                0.975127  0.195338  1.000000  0.974701  0.975223   0.884435
# y                0.951753  0.183756  0.974701  1.000000  0.956305   0.865421
# z                0.958075  0.151758  0.975223  0.956305  1.000000   0.865153
# price_new        0.921611  0.127068  0.884435  0.865421  0.865153   1.000000
# encoded_color    0.290016  0.027330  0.268768  0.262104  0.267926   0.171305
# encoded_cut      0.017116  0.150387  0.022342  0.027572  0.002018   0.039860
# encoded_clarity -0.214565 -0.088294 -0.225721 -0.217616 -0.225894  -0.071535
#
#                  encoded_color  encoded_cut  encoded_clarity
# carat                 0.290016     0.017116        -0.214565
# table                 0.027330     0.150387        -0.088294
# ...

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>
